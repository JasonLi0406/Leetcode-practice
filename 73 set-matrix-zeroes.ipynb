# %%
class Solution(object):
    def setZeroes(self, matrix):
        """
        :type matrix: List[List[int]]
        :rtype: None Do not return anything, modify matrix in-place instead.
        """
        getRowZero, getColZero = [], []
        m = len(matrix)
        n = len(matrix[0])

        for row in range(m):
            for col in range(n):
                if matrix[row][col] == 0:
                    getRowZero.append(row)
                    getColZero.append(col)
        
        for row in getRowZero:
            for col in range(n):
                matrix[row][col] = 0
        
        for col in getColZero:
            for row in range(m):
                matrix[row][col] = 0
        
        return matrix

# %%
def setZeroes(matrix):
    """
    :type matrix: List[List[int]]
    :rtype: None Do not return anything, modify matrix in-place instead.
    """
    getRowZero, getColZero = [], []
    m = len(matrix)
    n = len(matrix[0])

    for row in range(m):
        for col in range(n):
            if matrix[row][col] == 0:
                getRowZero.append(row)
                getColZero.append(col)
    
    for row in getRowZero:
        for col in range(n):
            matrix[row][col] = 0
    
    for col in getColZero:
        for row in range(m):
            matrix[row][col] = 0
    
    return matrix

# %%
matrix = [[0,1,2,0],[3,4,5,2],[1,3,1,5]]
print(matrix)

print(setZeroes(matrix))
# Out:
# [[0, 1, 2, 0], [3, 4, 5, 2], [1, 3, 1, 5]]
# [[0, 0, 0, 0], [0, 4, 5, 0], [0, 3, 1, 0]]
