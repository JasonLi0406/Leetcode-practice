# %%
class Solution(object):
    def closestPrimes(self, left, right):
        """
        :type left: int
        :type right: int
        :rtype: List[int]
        """
        
    # Find the prime number
        def isPrime(n):
            # Remove even number
            if (n%2)==0 and n!=2:
                return False

            # Remove "one"
            if n==1:
                return False
            
            # Find prime number
            for i in range(3, int(n**0.5)+2, 2):
                if (n%i)==0:
                    return False
                
            return True
        
        # Main program
        prime = []

        for i in range(left, right+1):
            # Add to the list if the number is prime
            if isPrime(i):
                prime.append(i)

                # Early break check
                if len(prime) > 1:
                    if (prime[-1] - prime[-2] == 2):
                        return [prime[-2], prime[-1]]
                    
                    if (prime[-1] - prime[-2] == 1):
                        return [prime[-2], prime[-1]]

        # No enough prime number
        if len(prime) < 2:
            return [-1, -1]
        
        # Find the minimum prime number difference
        diff = [prime[i+1]-prime[i] for i in range(len(prime)-1)]
        id = diff.index(min(diff))

        return [prime[id], prime[id+1]]

# %%
def closestPrimes(self, left, right):
    """
    :type left: int
    :type right: int
    :rtype: List[int]
    """
    
# Find the prime number
    def isPrime(n):
        # Remove even number
        if (n%2)==0 and n!=2:
            return False

        # Remove "one"
        if n==1:
            return False
        
        # Find prime number
        for i in range(3, int(n**0.5)+2, 2):
            if (n%i)==0:
                return False
            
        return True
    
    # Main program
    prime = []

    for i in range(left, right+1):
        # Add to the list if the number is prime
        if isPrime(i):
            prime.append(i)

            # Early break check
            if len(prime) > 1:
                if (prime[-1] - prime[-2] == 2):
                    return [prime[-2], prime[-1]]
                
                if (prime[-1] - prime[-2] == 1):
                    return [prime[-2], prime[-1]]

    # No enough prime number
    if len(prime) < 2:
        return [-1, -1]
    
    # Find the minimum prime number difference
    diff = [prime[i+1]-prime[i] for i in range(len(prime)-1)]
    id = diff.index(min(diff))

    return [prime[id], prime[id+1]]

# %%
left = 1
right = 1000000

print(closestPrimes(left, right))
