# %%
class Solution(object):
    def maximumTripletValue(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        n = len(nums)
        prefix_max = [0] * n
        suffix_max = [0] * n

        for i in range(1, n):
            prefix_max[i] = max(prefix_max[i-1], nums[i-1])
            suffix_max[n-1-i] = max(suffix_max[n-i], nums[n-i])

        maximum = 0
        for j in range(1, n-1):
            current = (prefix_max[j] - nums[j]) * suffix_max[j]
            maximum =  current if current > maximum else maximum
        
        return maximum

# %%
def maximumTripletValue(nums):
    """
    :type nums: List[int]
    :rtype: int
    """
    n = len(nums)
    prefix_max = [0] * n
    suffix_max = [0] * n

    for i in range(1, n):
        prefix_max[i] = max(prefix_max[i-1], nums[i-1])
        suffix_max[n-1-i] = max(suffix_max[n-i], nums[n-i])

    maximum = 0
    for j in range(1, n-1):
        current = (prefix_max[j] - nums[j]) * suffix_max[j]
        maximum =  current if current > maximum else maximum
    
    return maximum
