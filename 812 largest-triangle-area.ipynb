# %%
class Solution(object):
    def largestTriangleArea(self, points):
        """
        :type points: List[List[int]]
        :rtype: float
        """
        def countTriangleArea(p1, p2, p3):
            return abs((p1[0] * (p2[1] - p3[1]) + p2[0] * (p3[1] - p1[1]) + p3[0] * (p1[1] - p2[1])) / 2)
        
        maxArea = 0
        n = len(points)
        for i in range(n-2):
            for j in range(i + 1, n-1):
                for k in range(j + 1, n):
                    maxArea = max(maxArea, countTriangleArea(points[i], points[j], points[k]))

        return maxArea

# %%
def largestTriangleArea(points):
    """
    :type points: List[List[int]]
    :rtype: float
    """
    
    def countTriangleArea(p1, p2, p3):
        return abs((p1[0] * (p2[1] - p3[1]) + p2[0] * (p3[1] - p1[1]) + p3[0] * (p1[1] - p2[1])) / 2)
    
    maxArea = 0
    n = len(points)
    for i in range(n-2):
        for j in range(i + 1, n-1):
            for k in range(j + 1, n):
                maxArea = max(maxArea, countTriangleArea(points[i], points[j], points[k]))

    return maxArea

# %%
points = [[1,0],[0,0],[0,1]]

largestTriangleArea(points)
# Out:
# 0.5
