# %%
class Solution(object):
    def pivotIndex(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        
        if len(nums) == 1:
            return 0
        
        AddFromLeft = [0] * len(nums)
        AddFromRight = [0] * len(nums)

        AddFromLeft[0] = nums[0]
        for i in range(1, len(nums)):
            AddFromLeft[i] = AddFromLeft[i-1] + nums[i]
        
        AddFromRight[-1] = nums[-1]
        for i in range(len(nums)-2, -1, -1):
            AddFromRight[i] = AddFromRight[i+1] + nums[i]

        # print(AddFromLeft)
        # print(AddFromRight)
        
        for i in range(len(nums)):
            if AddFromLeft[i] == AddFromRight[i]:
                return i
                
        return -1

# %%
def pivotIndex(nums):
    """
    :type nums: List[int]
    :rtype: int
    """
    if len(nums) == 1:
        return 0
    
    AddFromLeft = [0] * len(nums)
    AddFromRight = [0] * len(nums)

    AddFromLeft[0] = nums[0]
    for i in range(1, len(nums)):
        AddFromLeft[i] = AddFromLeft[i-1] + nums[i]
    
    AddFromRight[-1] = nums[-1]
    for i in range(len(nums)-2, -1, -1):
        AddFromRight[i] = AddFromRight[i+1] + nums[i]

    # print(AddFromLeft)
    # print(AddFromRight)
    
    for i in range(len(nums)):
        if AddFromLeft[i] == AddFromRight[i]:
            return i
            
    return -1

# %%
nums = [1,7,3,6,5,6]

pivotIndex(nums)
# Out:
# [1, 8, 11, 17, 22, 28]
# [28, 27, 20, 17, 11, 6]
# 3
