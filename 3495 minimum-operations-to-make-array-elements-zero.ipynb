# %%
class Solution(object):
    def minOperations(self, queries):
        """
        :type queries: List[List[int]]
        :rtype: int
        """
        def bit4(n):
            return (n.bit_length()+1) // 2

        def count(n):
            if n == 0:
                return 0
            
            else:
                sum = 0
                for i in range(1, bit4(n)):
                    sum += (4**i - 4**(i-1)) * i
                sum += (n - 4**(bit4(n)-1) + 1) * bit4(n)
                return sum

        res = 0
        for query in queries:
            res += (count(query[1]) - count(query[0]-1) + 1)//2
        return res

# %%
def minOperations(queries):
    """
    :type queries: List[List[int]]
    :rtype: int
    """
    def bit4(n):
        return (n.bit_length()+1) // 2

    def count(n):
        if n == 0:
            return 0
        
        else:
            sum = 0
            for i in range(1, bit4(n)):
                sum += (4**i - 4**(i-1)) * i
            sum += (n - 4**(bit4(n)-1) + 1) * bit4(n)
            return sum

    res = 0
    for query in queries:
        res += (count(query[1]) - count(query[0]-1) + 1)//2
    return res

# %%
def bit4(n):
    return (n.bit_length()+1) // 2

def count(n):
    if n == 0:
        return 0
    
    else:
        sum = 0
        for i in range(1, bit4(n)):
            sum += (4**i - 4**(i-1)) * i
        sum += (n - 4**(bit4(n)-1) + 1) * bit4(n)
        return sum

def minOperations(queries):
    res = 0
    for query in queries:
        res +=(count(query[1]) - count(query[0]-1) + 1)//2
    return res

# %%
queries = [[2, 6]]

print(minOperations(queries))
# Out:
# 4
