# %%
class Solution:
    def mirrorDistance(self, n: int) -> int:
        return abs(int(str(n)[::-1]) - n)

# %%
def mirrorDistance(n: int) -> int:
    return abs(int(str(n)[::-1]) - n)

# %%
n = 25

mirrorDistance(n)
# Out:
# 27
