# %%
class Solution(object):
    def hasIncreasingSubarrays(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: bool
        """
        number_of_increasing_subarray = []

        cnt = 1
        for i in range(len(nums)-1):
            if nums[i] < nums[i+1]:
                cnt += 1
            else:
                number_of_increasing_subarray.append(cnt)
                cnt = 1

        number_of_increasing_subarray.append(cnt)

        # print(number_of_increasing_subarray)

        if len(number_of_increasing_subarray) == 1:
            return True if number_of_increasing_subarray[0] >= 2 * k else False

        for i in range(len(number_of_increasing_subarray)-1):
            if number_of_increasing_subarray[i] >= 2 * k:
                return True
            if (number_of_increasing_subarray[i] >= k) and (number_of_increasing_subarray[i+1] >= k):
                return True

        return False

# %%
def hasIncreasingSubarrays(nums, k):
    """
    :type nums: List[int]
    :type k: int
    :rtype: bool
    """
    number_of_increasing_subarray = []

    cnt = 1
    for i in range(len(nums)-1):
        if nums[i] < nums[i+1]:
            cnt += 1
        else:
            number_of_increasing_subarray.append(cnt)
            cnt = 1

    number_of_increasing_subarray.append(cnt)

    print(number_of_increasing_subarray)

    if len(number_of_increasing_subarray) == 1:
        return True if number_of_increasing_subarray[0] >= 2 * k else False

    for i in range(len(number_of_increasing_subarray)-1):
        if number_of_increasing_subarray[i] >= 2 * k:
            return True
        if (number_of_increasing_subarray[i] >= k) and (number_of_increasing_subarray[i+1] >= k):
            return True

    return True if number_of_increasing_subarray[-1] >= 2 * k else False

# %%
nums = [8,-4,-1,16,20]
k = 2

hasIncreasingSubarrays(nums, k)
# Out:
# [1, 4]
# True
