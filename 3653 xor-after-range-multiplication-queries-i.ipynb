# %%
from typing import List

# %%
class Solution:
    def xorAfterQueries(self, nums: List[int], queries: List[List[int]]) -> int:
        MOD = 10**9 + 7
        for start, end, interval, multiple in queries:
            for i in range(start, end+1, interval):
                nums[i] = (nums[i] * multiple) % MOD

        res = nums[0]
        for i in range(1, len(nums)):
            res ^= nums[i]
        
        return res

# %%
def xorAfterQueries(nums: List[int], queries: List[List[int]]) -> int:
    MOD = 10**9 + 7
    for start, end, interval, multiple in queries:
        for i in range(start, end+1, interval):
            nums[i] = (nums[i] * multiple) % MOD
    
    print(nums)

    res = nums[0]
    for i in range(1, len(nums)):
        res ^= nums[i]
    
    return res

# %%
nums = [1,1,1]
queries = [[0,2,1,4]]

xorAfterQueries(nums, queries)
# Out:
# [4, 4, 4]
# 4
