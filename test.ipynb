# %%
s = '''Even though there is a significant development in taming
RuO2, the stability outcomes observed in the controlled
conditions of standard three-electrode setups with acidic liquid
electrolytes may not directly apply to actual PEMWE
electrolyzers, owing to substantial differences in reaction
environments.38,39 This discrepancy also affects alkaline water
electrolysis (AWE), despite the development of various highperformance
OER catalysts in alkaline media.40,41 To bridge
this gap, it is essential to conduct comprehensive accelerated
stress testing (AST) across both laboratory and actual
PEMWE or AWE setups to accurately assess the performance
of RuO2 catalysts.16,42,43 Concurrently, exploring straightforward
modification techniques could facilitate the swift
advancement and practical deployment of RuO2, addressing
the dual challenges of activity enhancement and stability in
OER.'''

s = s.replace('\n', ' ')
print(s)
# Out:
# Even though there is a significant development in taming RuO2, the stability outcomes observed in the controlled conditions of standard three-electrode setups with acidic liquid electrolytes may not directly apply to actual PEMWE electrolyzers, owing to substantial differences in reaction environments.38,39 This discrepancy also affects alkaline water electrolysis (AWE), despite the development of various highperformance OER catalysts in alkaline media.40,41 To bridge this gap, it is essential to conduct comprehensive accelerated stress testing (AST) across both laboratory and actual PEMWE or AWE setups to accurately assess the performance of RuO2 catalysts.16,42,43 Concurrently, exploring straightforward modification techniques could facilitate the swift advancement and practical deployment of RuO2, addressing the dual challenges of activity enhancement and stability in OER.

# %%
n = 7

a, b = divmod(n, 2)

a, b
# Out:
# (3, 1)
