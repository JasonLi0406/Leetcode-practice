# %%
class Solution:
    def maxOperations(self, s: str) -> int:
        res = 0
        ones = 0
        TF = False
        
        for i in s:
            if i == '1':
                ones += 1
                TF = True
            elif TF:
                res += ones
                TF = False
                    
        return res

# %%
def maxOperations(s: str) -> int:
    res = 0
    ones = 0
    TF = False
    
    for i in s:
        if i == '1':
            ones += 1
            TF = True
        elif TF:
            res += ones
            TF = False

    return res

# %%
s = '00111'

maxOperations(s)
# Out:
# 0
